# %% [markdown]
# ### **Importing Libraries**

# %%
import pickle
import sys
import os

# %% [markdown]
# ### **Adding Root Directory to the System Path**

# %%
notebook_dir = os.path.dirname(os.path.abspath('__file__'))
root_dir = os.path.dirname(notebook_dir)
sys.path.insert(0, root_dir)

# %% [markdown]
# ### **Importing DKTDataset Class**
# It is necessary as in the pickle files objects of DKTDataset are stored, so it is required to assess the split.

# %%
from preprocessing.dkt_format_adapter import DKTDataset

# %% [markdown]
# ### **Loading Splits**

# %% [markdown]
# #### **1. Standard Splits (Binary)**

# %%
train_standard = '../data/processed/dkt_format/dkt_format_binary/train_standard_dkt.pkl'
val_standard = '../data/processed/dkt_format/dkt_format_binary/val_standard_dkt.pkl'
test_standard = '../data/processed/dkt_format/dkt_format_binary/test_standard_dkt.pkl'

with open(train_standard, 'rb') as file:
    train_standard_data = pickle.load(file)
with open(val_standard, 'rb') as file:
    val_standard_data = pickle.load(file)
with open(test_standard, 'rb') as file:
    test_standard_data = pickle.load(file)

# %% [markdown]
# #### **2. Domain Shift Splits (Binary)**

# %%
train_domain_shift = '../data/processed/dkt_format/dkt_format_binary/train_domain_shift_dkt.pkl'
val_domain_shift = '../data/processed/dkt_format/dkt_format_binary/val_domain_shift_dkt.pkl'
test_domain_shift = '../data/processed/dkt_format/dkt_format_binary/test_domain_shift_dkt.pkl'

with open(train_domain_shift, 'rb') as file:
    train_domain_shift_data = pickle.load(file)
with open(val_domain_shift, 'rb') as file:
    val_domain_shift_data = pickle.load(file)
with open(test_domain_shift, 'rb') as file:
    test_domain_shift_data = pickle.load(file)

# %% [markdown]
# #### **3. Standard Splits (Multiclass)**

# %%
train_standard = '../data/processed/dkt_format/dkt_format_multiclass/train_standard_dkt.pkl'
val_standard = '../data/processed/dkt_format/dkt_format_multiclass/val_standard_dkt.pkl'
test_standard = '../data/processed/dkt_format/dkt_format_multiclass/test_standard_dkt.pkl'

with open(train_standard, 'rb') as file:
    train_standard_data = pickle.load(file)
with open(val_standard, 'rb') as file:
    val_standard_data = pickle.load(file)
with open(test_standard, 'rb') as file:
    test_standard_data = pickle.load(file)

# %% [markdown]
# #### **4. Domain Shift Splits (Multiclass)**

# %%
train_domain_shift = '../data/processed/dkt_format/dkt_format_multiclass/train_domain_shift_dkt.pkl'
val_domain_shift = '../data/processed/dkt_format/dkt_format_multiclass/val_domain_shift_dkt.pkl'
test_domain_shift = '../data/processed/dkt_format/dkt_format_multiclass/test_domain_shift_dkt.pkl'

with open(train_domain_shift, 'rb') as file:
    train_domain_shift_data = pickle.load(file)
with open(val_domain_shift, 'rb') as file:
    val_domain_shift_data = pickle.load(file)
with open(test_domain_shift, 'rb') as file:
    test_domain_shift_data = pickle.load(file)
